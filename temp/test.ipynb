# %% [markdown]
# # temp

# %%
import sys

sys.path.append("/Users/chengjy/ChengJunyan1/ws/lllm")

from lllm import Tactic

_, agent = Tactic.quick("Good morning.", model="gpt-4o", return_agent=True)
agent.open("new_chat")
agent.receive("What is the capital of France?")
print(agent.respond().content)
# Out:
# The capital of France is Paris.

# %%
print(agent._dialogs['chat'].overview())

# %%
from lllm.core.runtime import get_default_runtime

runtime = get_default_runtime()

# %%
runtime._resources
