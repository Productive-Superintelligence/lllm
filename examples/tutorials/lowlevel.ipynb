# %% [markdown]
# # Low-level models inside LLLM

# %% [markdown]
# ## Model caller
#
# How LLLM handle low-level foundation model calls?

# %%
import os, sys
import dotenv
from pathlib import Path


# Set your API keys either through environment variables or a .env file

dotenv.load_dotenv()

assert 'OPENAI_API_KEY' in os.environ, "OPENAI_API_KEY is not set"
assert 'ANTHROPIC_API_KEY' in os.environ, "ANTHROPIC_API_KEY is not set"
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 5
#       2 import dotenv
#       3 from pathlib import Path
# ----> 5 CUR_DIR = Path(__file__).parent
#       7 # Set your API keys either through environment variables or a .env file
#       9 dotenv.load_dotenv()
#
# NameError: name '__file__' is not defined

# %% [markdown]
# ### Model Cards and Model Callers

# %%
print(Path(__file__).parent)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 print(Path(__file__).parent)
#
# NameError: name 'Path' is not defined

# %%
from lllm.core.const import MODEL_CARDS, load_model_cards_from_file



# LLLM will automatically load builtin model cards
MODEL_CARDS

# user can also provide a custom model cards file as it may not update frequently, same name model will be overwritten
load_model_cards_from_file('./tutorials/example_modelcard.toml')
# Out:
# WARNING:root:Model cards file tutorials/example_modelcard.toml not found
